# %%
import pandas as pd
import numpy as np

# %%
pd.read_csv("junction/Junction_Data.csv", nrows=1000, delimiter=';')
# Out:
#       Receipt TransactionDate  BeginHour            EAN  Quantity  \
# 0    13735389      2017-01-01         21  4001724819608  1,000000
# 1    13735389      2017-01-01         21  6411402197108  1,000000
# 2    13735438      2017-01-01         13  6411402202208  1,000000
# 3    13735438      2017-01-01         13  6407810016636  1,000000
# 4    13735438      2017-01-01         13  6416046654123  1,000000
# 5    13735438      2017-01-01         13  2000619500005  0,844000
# 6    13735438      2017-01-01         13  6408430310869  1,000000
# 7    13735438      2017-01-01         13  2000797000007  0,996000
# 8    13735438      2017-01-01         13  5410146414497  1,000000
# 9    13735438      2017-01-01         13  8718114868943  1,000000
# 10   13735438      2017-01-01         13  6408430000548  1,000000
# 11   13735438      2017-01-01         13  6409290001492  1,000000
# 12   13735613      2017-01-01         15  7622100936077  1,000000
# ...

# %%
def request(req_type="POST", url):
    headers = {
        'Ocp-Apim-Subscription-Key': '{subscription key}',
    }

    params = urllib.parse.urlencode({
    })

    try:
        conn = http.client.HTTPSConnection('kesko.azure-api.net')
        conn.request(req_type, "/files/store_services?%s" % params, "{body}", headers)
        response = conn.getresponse()
        data = response.read()
        print(data)
        conn.close()
    except Exception as e:
        print("[Errno {0}] {1}".format(e.errno, e.strerror))

# %%
import http.client, urllib.request, urllib.parse, urllib.error, base64
key = '7cfcc232a2294794815127a7dcfc9b73'

headers = {
    'Ocp-Apim-Subscription-Key': '{}'.format(key),
}

params = urllib.parse.urlencode({
})

try:
    conn = http.client.HTTPSConnection('kesko.azure-api.net')
    conn.request("POST", "/files/store_services?%s" % params, "{body}", headers)
    response = conn.getresponse()
    data = response.read()
    print(data)
    conn.close()
except Exception as e:
    print("[Errno {0}] {1}".format(e.errno, e.strerror))
# Out:
# b'{"uri":"https://keskojunction.file.core.windows.net/data/Junction-Kesko-store_services.xlsx?st=2018-11-24T09%3A19%3A50Z&se=2018-11-24T09%3A34%3A50Z&sp=r&sv=2018-03-28&sr=f&sig=ue%2BpAH23GZ8NXAFm5vCYJyJfBOgp6QwbB0xyVjhZyaI%3D","expires_at":"2018-11-24T09:34:50.998Z"}'

# %%
def get_name_by_ean_and_storeid(ean='5060107330368', store_id='K171', key='7cfcc232a2294794815127a7dcfc9b73'):
    headers = {
        # Request headers
        'Ocp-Apim-Subscription-Key': '{}'.format(key),
    }

    params = urllib.parse.urlencode({
    })

    try:
        conn = http.client.HTTPSConnection('kesko.azure-api.net')
        conn.request("GET", "/products/{storeId}/{ean}?%s".format(storeId=store_id, ean=ean) % params, "{body}", headers)
        response = conn.getresponse()
        data = response.read()
        print(data)
        conn.close()
    except Exception as e:
        print("[Errno {0}] {1}".format(e.errno, e.strerror))

# %%
def get_store_info_by_storeid(store_id='K171', key='7cfcc232a2294794815127a7dcfc9b73'):
    headers = {
        # Request headers
        'Ocp-Apim-Subscription-Key': '{}'.format(key),
    }

    params = urllib.parse.urlencode({
    })

    try:
        conn = http.client.HTTPSConnection('kesko.azure-api.net')
        conn.request("GET", "/v2/stores/{storeId}?%s".format(storeId=store_id) % params, "{body}", headers)
        response = conn.getresponse()
        data = response.read()
        print(data)
        conn.close()
    except Exception as e:
        print("[Errno {0}] {1}".format(e.errno, e.strerror))

# %%
get_store_info_by_storeid()
# Out:
# b'{"id":"K171","name":"K-MARKET OTANIEMI","update":4262612}'

# %%
get_name_by_ean_and_storeid()
# Out:
# b'{"ean":"5060107330368","name":"Ella\'s mansikka-omena 120g 4kk Luomu","group":"13510","price":2.29,"pricingUnit":"kpl","vat":14,"packageSize":"120.00","packageUnit":null,"packageType":"pussi","costCenterId":"TE01","plussaLimited":false,"discountLimited":false,"type":"CONSUMER_GOOD","totalPrice":2.29}'

# %%
nutrition_types = {
    'The Beginner Meal Plan': [
        '''Target: 2,500 calories, 218 g carbs, 218 g protein, 83 g fat''',
        '''If you want to stay healthy and have more energy, this is the plan for you.'''
    ],
    'The Skinny Guy Muscle-Gain Plan': [
        '''Target: approx. 3,000 calories, 300 g carbs, 225 g protein, 100 g fat''',
        '''Forging new muscle requires a menu that is high in both carbs and calories.'''
    ],
    'The Get-Lean Meal Plan' : [
        '''Target: 2000 calories, 150 g carbs, 150 g protein, 88 g fat''',
        '''To accelerate your weight loss, limit starchy carbs to the period directly after training.'''
    ], 
    'Vegetarian Balanced Meal Plan' : [
        '''Target: 2200 calories, 250 g carbs, 85 g protein, 80 g fat''',
        '''Balanced plan to stay healty eating vegetarian meals.'''
    ], 
    'Vegan Meal Plan': [
        '''Target: ???''', 
        '''A vegan diet contains only plants (such as vegetables, grains, nuts and fruits) and foods made from plants.'''
    ],
    'Ketogenic Meal Plan' : [
        '''Target: ???''',
        '''The ketogenic diet is a high-fat, adequate-protein, low-carbohydrate diet.'''
    ],
    'Paleo Meal Plan' : [
        '''Target: ???''',
        '''A paleo diet is a dietary plan based on foods similar to what might have been eaten during the Paleolithic era.'''
    ],
    'Fertility Meal Plan': [
        '''Target: ???''',
        '''Eating slow carbs help to minimize insulin resistance, regulate blood sugar, improve fertility and prevent gestational diabetes.'''
    ]
}

# %%
plan_names = list(nutrition_types.keys())

# %%
plan_names = [
 'The Beginner Meal Plan',
 'The Muscle-Gain Plan',
 'The Get-Lean Meal Plan',
 'Vegetarian Balanced Meal Plan',
 'Vegan Meal Plan',
 'Ketogenic Meal Plan',
 'Paleo Meal Plan',
 'Fertility Meal Plan']

# %%
plan_descrs = [
 '''If you want to stay healthy and have more energy, this is the plan for you.''',
 '''Forging new muscle requires a menu that is high in both carbs and calories.''',
 '''To accelerate your weight loss, limit starchy carbs to the period directly after training.''',
 '''Balanced plan to stay healty eating vegetarian meals.''',
 '''A vegan diet contains only plants (such as vegetables, grains, nuts and fruits) and foods made from plants.''',
 '''The ketogenic diet is a high-fat, adequate-protein, low-carbohydrate diet.''',
 '''A paleo diet is a dietary plan based on foods similar to what might have been eaten during the Paleolithic era.''',
 '''Eating slow carbs help to minimize insulin resistance, regulate blood sugar, improve fertility and prevent gestational diabetes.'''
]

# %%
beginner_plan = ['Greek Yogurt', 'Raspberries', 'Tomato', 'Beef', 'Beans', 'Spinach', 'Bell pepper', 'Shrimps']
muscle_plan = ['Eggs', 'Almonds', 'Cucumber', 'Red Meat', 'Chickpeas', 'Chicken', 'White fish', 'Broccoli', 'Butter', 'Parmesan Cheese']
lean_plan = ['Eggs', 'Cheese', 'Spinach', 'Chia Seeds', 'Strawberries', 'Steak', 'Avocado', 'Tomato', 'Mushrooms', 'Broccoli']
vegetarian_plan = ['Milk', 'Eggs', 'Bell pepper', 'Carrot', 'Tofu', 'Bananas', 'Corn', 'Brown Rice', 'Avocado', 'Yogurt', 'Brussels sprouts']
vegan_plan = ['Tofu', 'Almond Milk', 'Carrot', 'Brown Rice', 'Broccoli', 'Spinach', 'Asparagus', 'Pasta', 'Cashews', 'Beans']
keto_plan = ['Eggs', 'Cheese', 'Shrimps', 'Red Meat', 'Avocado', 'Broccoli', 'Brazil Nuts', 'Fresh Fish', 'Mushrooms', 'Wallnuts']
paleo_plan = ['Fish', 'Eggs', 'Avocado', 'Broccoli', 'Potato', 'Nuts', 'Mushrooms', 'Diet Soda', ]
